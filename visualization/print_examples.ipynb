# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
run_folder_name = "C-LBBDM-Low-Variance-Long"
gt_file = "gt_epoch_7_step_50000.npy"
val_file = "validation_epoch_7_step_50000.npy"

# %%
# from the logs, load the validation ground truth and reconstructed numpy arrays.
gt = np.load(f"../logs/{run_folder_name}/validation/{gt_file}")
val = np.load(f"../logs/{run_folder_name}/validation/{val_file}")

# %%
i = 7

# %%
plt.imshow(val[i][0].transpose(), aspect='auto')

# %%
plt.imshow(gt[i][0].transpose(), aspect='auto')
